# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(n_samples= 300 , centers= 5 , cluster_std = 0.80, random_state = 0)

# %%
plt.scatter(X[:, 0],X[: , 1] , s = 50)
# colon means rows value while after comma valure is column
plt.xlabel('Feature 1')
plt.ylabel('Feature 1')
plt.title('Synthetic Data')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X[:5, 0]
# Out:
# array([10.15348268, -0.34538052,  0.42061579,  8.19491487, -1.13191059])

# %%
X[:5]
# Out:
# array([[10.15348268, -1.29275205],
#        [-0.34538052,  8.23226077],
#        [ 0.42061579,  4.1840797 ],
#        [ 8.19491487, -2.94042833],
#        [-1.13191059,  2.82499911]])

# %%
X[:5,1]
#5worta row of 2nd column
# Out:
# array([-1.29275205,  8.23226077,  4.1840797 , -2.94042833,  2.82499911])

# %%
k=4
#k is the number of cluseter

# %%
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
labels = kmeans.labels_ 
centroids = kmeans.cluster_centers_

# %%
plt.scatter(X[:, 0], X[:,1], c =labels, cmap= 'viridis', s = 40)
plt.scatter(centroids[:, 0], centroids[:,1], c = 'red', marker= '*',s = 200)
plt.show()

# %%
inertias = []

for i in range (1,5):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(X)
  inertias.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(range(1,5),inertias)
plt.ylabel('Inertia')
plt.xlabel('Iteration')
#elbow method
#1000-8000 inertia
#1-4 iteration
